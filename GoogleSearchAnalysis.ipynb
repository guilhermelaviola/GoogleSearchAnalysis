# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/GoogleSearchAnalysis/blob/main/GoogleSearchAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pytrends

# %%
# Importing all the necessary libraries:
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt

# %%
# Google Trends provides an API called pytrends that can be used
# to analyze the daily searches on Google.
trends = TrendReq()

# %%
# Analyzing the Google search trends on the queries based on Champions League
# and creating a dataframe of the top 10 countries which search for
# 'UEFA Champions League' on Google:
trends.build_payload(kw_list = ['Champions League'])
data = trends.interest_by_region()
data = data.sort_values(by = 'Champions League', ascending = False)
data = data.head(10)
print(data)
# Out:
#            Champions League
# geoName
# Uganda                  100
# Cameroon                 75
# Zimbabwe                 64
# Ethiopia                 64
# Ghana                    64
# Zambia                   63
# Cuba                     56
# Nigeria                  56
# Kenya                    53
# Mauritius                52

# %%
# Displaying the results in a bar chart:
data.reset_index().plot(x = 'geoName',
                        y = 'Champions League',
                        figsize = (15, 12),
                        kind = 'bar')
plt.style.use('fivethirtyeight')
plt.show()

# %%
# Checking how the search queries based on 'Champions League' increased
# or decreased on Google in the past years:
data = TrendReq(hl = 'en-US', tz = 360)
data.build_payload(kw_list = ['Champions League'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize = (15, 12))
data['Champions League'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Champions League',
          fontweight = 'bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
